# %%
import qiskit
import numpy as np
import matplotlib.pyplot as plt
import math
from qiskit_aer import AerSimulator
from sklearn.preprocessing import normalize

# %% [markdown]
# Create a random sample of which we will take the Fourier transform:

# %%
sample = np.random.rand(16)
sample_norm = normalize(sample.reshape(1, -1), norm='l2')[0]

# %% [markdown]
# Calculate the number of qubits needed for the normalized sample:

# %%
n = len(sample_norm)
q = int(math.log(n,2))
f"Num qubits: {q}"
# Out:
# 'Num qubits: 4'

# %% [markdown]
# Create a quantum circuit, add QFT with swaps to this circuit:

# %%
circuit = qiskit.QuantumCircuit(q)
circuit.initialize(sample_norm, range(q))

# %%
qft = qiskit.circuit.library.QFT(num_qubits=q, do_swaps=True)
circuit.compose(qft, inplace=True)
circuit.save_statevector()

# %% [markdown]
# Simulate using Aer to get the result of the statevector:

# %%
backend = AerSimulator()
result = backend.run(circuit.decompose(reps=16)).result()
qft_state = result.get_statevector()

# %% [markdown]
# Compare the power spectral density of the QFT vs the classical FFT to check our result:

# %%
PSD_q = np.abs(qft_state)**2

# %%
f = sample_norm
fhat = np.fft.fft(f, n)
PSD = np.abs(fhat)**2 / n

# %%
plt.title('Power Spectral Density (PSD) of QFT vs Classical FFT')
plt.plot(PSD_q, color='r', linewidth=2, label='QFT')
plt.plot(PSD, color='c', linestyle='dashed', linewidth=2, label='Classical FFT')
plt.xlim(0, n-1)
plt.legend()
plt.show()

# %% [markdown]
# The QFT circuit is the following:

# %%
circuit = circuit.decompose(reps=7)

circuit.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %% [markdown]
# We would like to cut this circuit.

# %%
from qiskit.circuit.random import random_circuit

from circuit_knitting.cutting.gate_and_wire_cutting.frontend import cut_wires_and_gates_to_subcircuits
from circuit_knitting.cutting.gate_and_wire_cutting.frontend import execute_simulation
from circuit_knitting.cutting.cutting_reconstruction import reconstruct_expectation_values
from circuit_knitting.cutting.gate_and_wire_cutting.frontend import exact_observables
from circuit_knitting.cutting.gate_and_wire_cutting.frontend import compare_results
# Out:
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(

# %% [markdown]
# We would like to measure in the Z basis:

# %%
observables = ['Z'*q]

# %% [markdown]
# Now we cut our circuit:

# %%
subcircuits, subobservables = cut_wires_and_gates_to_subcircuits(
    circuit=circuit,
    observables=observables,
    method='automatic',
    max_subcircuit_width=2,
    max_cuts=100,
    num_subcircuits=[2],
    model='gurobi'
)
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Set parameter TimeLimit to value 300
# Set parameter Cutoff to value 1e+100
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 833 rows, 335 columns and 2894 nonzeros
# Model fingerprint: 0x0c411340
# Variable types: 0 continuous, 335 integer (320 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+02]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 833 rows and 335 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
# MIP MODEL CUT EDGES:  [('q[3]0', 'q[2]0'), ('q[3]1', 'q[2]1'), ('q[3]2', 'q[1]1'), ('q[3]3', 'q[1]3'), ('q[1]4', 'q[0]0'), ('q[2]4', 'q[0]1'), ('q[1]5', 'q[0]2'), ('q[1]6', 'q[0]4'), ('q[2]5', 'q[0]5'), ('q[1]7', 'q[0]6'), ('q[3]6', 'q[2]6'), ('q[3]7', 'q[2]7'), ('q[3]8', 'q[1]8'), ('q[3]9', 'q[1]9'), ('q[2]10', 'q[0]10'), ('q[2]11', 'q[0]11'), ('q[1]12', 'q[0]12'), ('q[1]13', 'q[0]13')]

# %% [markdown]
# Let's visualize our subcircuits:

# %%
subcircuits[0].draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
subcircuits[1].draw('mpl')

# %% [markdown]
# We can see that QFT with swaps produces subcircuits with no advantage. The gurobi solver fails if max subcircuit width is reduced.
#
# Let's try without swaps...

# %%
circuit_no_swaps = qiskit.QuantumCircuit(q)
circuit_no_swaps.initialize(sample_norm, range(q))

# %%
qft = qiskit.circuit.library.QFT(num_qubits=q, do_swaps=False)
circuit_no_swaps.compose(qft, inplace=True)
circuit_no_swaps.save_statevector()

# %%
circuit_no_swaps = circuit_no_swaps.decompose(reps=8)

circuit_no_swaps.draw('mpl')

# %%
subcircuits, subobservables = cut_wires_and_gates_to_subcircuits(
    circuit=circuit_no_swaps,
    observables=observables,
    method='automatic',
    max_subcircuit_width=4,
    max_cuts=10,
    num_subcircuits=[4],
    model='gurobi'
)
# Out:
# Set parameter TimeLimit to value 300
# Set parameter Cutoff to value 1e+100
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1297 rows, 547 columns and 4679 nonzeros
# Model fingerprint: 0x57ac100f
# Variable types: 0 continuous, 547 integer (520 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 69 rows and 37 columns
# Presolve time: 0.01s
# Presolved: 1228 rows, 510 columns, 4124 nonzeros
# Variable types: 0 continuous, 510 integer (496 binary)
# Found heuristic solution: objective 14.0000000
#
# Root relaxation: objective 2.221569e-01, 514 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.22216    0  229   14.00000    0.22216  98.4%     -    0s
# H    0     0                       9.0000000    0.22216  97.5%     -    0s
#      0     0    0.98979    0  244    9.00000    0.98979  89.0%     -    0s
#      0     0    0.99182    0  245    9.00000    0.99182  89.0%     -    0s
#      0     0    2.00000    0  273    9.00000    2.00000  77.8%     -    0s
#      0     0    2.00000    0  264    9.00000    2.00000  77.8%     -    0s
#      0     0    2.00000    0  265    9.00000    2.00000  77.8%     -    0s
#      0     0    2.00000    0  265    9.00000    2.00000  77.8%     -    0s
#      0     0    2.00000    0  282    9.00000    2.00000  77.8%     -    0s
#      0     0    2.00000    0  282    9.00000    2.00000  77.8%     -    0s
#      0     2    2.00000    0  282    9.00000    2.00000  77.8%     -    0s
# H   32    25                       8.0000000    2.17514  72.8%   210    0s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 9
#   MIR: 8
#   Flow cover: 1
#   Zero half: 23
#
# Explored 2183 nodes (291013 simplex iterations) in 3.63 seconds (5.51 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 8 9 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+00, best bound 8.000000000000e+00, gap 0.0000%
# MIP MODEL CUT EDGES:  [('q[2]2', 'q[1]0'), ('q[0]12', 'q[0]13'), ('q[1]0', 'q[1]1'), ('q[1]12', 'q[1]13'), ('q[1]13', 'q[0]13')]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 subcircuits, subobservables = cut_wires_and_gates_to_subcircuits(
#       2     circuit=circuit_no_swaps,
#       3     observables=observables,
#       4     method='automatic',
#       5     max_subcircuit_width=4,
#       6     max_cuts=10,
#       7     num_subcircuits=[4],
#       8     model='gurobi'
#       9 )
#
# File /mnt/c/Users/victoria.perrone/Documents/Projects/circuit-knitting-toolbox-modified/circuit_knitting/cutting/gate_and_wire_cutting/frontend.py:42, in cut_wires_and_gates_to_subcircuits(circuit, observables, method, max_subcircuit_width, max_cuts, num_subcircuits, model, verbose)
#      39 wire_cuts, gate_cuts = cut_list_to_wire_and_gates(cuts_list)
#      41 # Add gates to decompose given the cut locations
# ---> 42 ancilla_circ, cut_indices, qubit_mapping_ancilla = copy_and_add_ancilla(circuit, wire_cuts, gate_cuts)
#      44 # Account for increasing the number of qubits by adding 'I' observables
#      45 new_obs = add_I_observables(observables, qubit_mapping_ancilla, ancilla_circ.num_qubits)
#
# File /mnt/c/Users/victoria.perrone/Documents/Projects/circuit-knitting-toolbox-modified/circuit_knitting/cutting/gate_and_wire_cutting/util.py:158, in copy_and_add_ancilla(original_circ, wire_cut_locations, gate_cut_locations)
#     156 if qubit1 in gate_cut_dict and gate_index_dict[qubit_mapping[qubit1]] in gate_cut_dict[qubit1]:
#     157     cut_gate_indices.append(total_gate_index)
# --> 158 elif qubit2 in gate_cut_dict and gate_cut_dict[qubit2] == gate_index_dict[qubit_mapping[qubit2]]:
#     159     cut_gate_indices.append(total_gate_index)
#     161 # Check if there is a wire cut after this 2-qubit operation (on either, or both, of the 2 qubits)
#
# KeyError: Qubit(QuantumRegister(6, 'q91'), 5)

# %% [markdown]
# The gurobi solver could not find a solution.
#
# Let's try without initializing any data:

# %%
circuit_no_data = qiskit.QuantumCircuit(q)
qft = qiskit.circuit.library.QFT(num_qubits=q, do_swaps=False)
circuit_no_data.compose(qft, inplace=True)
circuit_no_data.save_statevector()
circuit_no_data = circuit_no_data.decompose(reps=7)
circuit_no_data.draw('mpl')

# %%
subcircuits, subobservables = cut_wires_and_gates_to_subcircuits(
    circuit=circuit_no_data,
    observables=observables,
    method='automatic',
    max_subcircuit_width=4,
    max_cuts=10,
    num_subcircuits=[2],
    model='gurobi'
)
# Out:
# Set parameter TimeLimit to value 300
# Set parameter Cutoff to value 1e+100
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 313 rows, 135 columns and 1054 nonzeros
# Model fingerprint: 0x3c9a0214
# Variable types: 0 continuous, 135 integer (120 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+00]
# Found heuristic solution: objective 12.0000000
# Presolve removed 57 rows and 42 columns
# Presolve time: 0.00s
# Presolved: 256 rows, 93 columns, 833 nonzeros
# Variable types: 0 continuous, 93 integer (87 binary)
#
# Root relaxation: objective 1.304348e-01, 70 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.13043    0   33   12.00000    0.13043  98.9%     -    0s
# H    0     0                       5.0000000    0.13043  97.4%     -    0s
# H    0     0                       3.0000000    0.13043  95.7%     -    0s
#      0     0    0.88889    0   37    3.00000    0.88889  70.4%     -    0s
#      0     0    3.00000    0   36    3.00000    3.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#
# Explored 1 nodes (233 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 3 5 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+00, best bound 3.000000000000e+00, gap 0.0000%
# MIP MODEL CUT EDGES:  [('q[1]5', 'q[0]5'), ('q[1]4', 'q[1]5')]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 subcircuits, subobservables = cut_wires_and_gates_to_subcircuits(
#       2     circuit=circuit_no_data,
#       3     observables=observables,
#       4     method='automatic',
#       5     max_subcircuit_width=4,
#       6     max_cuts=10,
#       7     num_subcircuits=[2],
#       8     model='gurobi'
#       9 )
#
# File /mnt/c/Users/victoria.perrone/Documents/Projects/circuit-knitting-toolbox-modified/circuit_knitting/cutting/gate_and_wire_cutting/frontend.py:42, in cut_wires_and_gates_to_subcircuits(circuit, observables, method, max_subcircuit_width, max_cuts, num_subcircuits, model, verbose)
#      39 wire_cuts, gate_cuts = cut_list_to_wire_and_gates(cuts_list)
#      41 # Add gates to decompose given the cut locations
# ---> 42 ancilla_circ, cut_indices, qubit_mapping_ancilla = copy_and_add_ancilla(circuit, wire_cuts, gate_cuts)
#      44 # Account for increasing the number of qubits by adding 'I' observables
#      45 new_obs = add_I_observables(observables, qubit_mapping_ancilla, ancilla_circ.num_qubits)
#
# File /mnt/c/Users/victoria.perrone/Documents/Projects/circuit-knitting-toolbox-modified/circuit_knitting/cutting/gate_and_wire_cutting/util.py:156, in copy_and_add_ancilla(original_circ, wire_cut_locations, gate_cut_locations)
#     154     gate_index_dict[ancilla_mapping_reverse[qubit_mapping[qubit2]]] += 1
#     155 # Check if the gate is a gate cut. If it is, add the total index to the list of cut gate indices
# --> 156 if qubit1 in gate_cut_dict and gate_index_dict[qubit_mapping[qubit1]] in gate_cut_dict[qubit1]:
#     157     cut_gate_indices.append(total_gate_index)
#     158 elif qubit2 in gate_cut_dict and gate_cut_dict[qubit2] == gate_index_dict[qubit_mapping[qubit2]]:
#
# KeyError: Qubit(QuantumRegister(5, 'q95'), 4)
